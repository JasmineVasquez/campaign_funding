# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import math

# %matplotlib inline

# %%
#CSV imports
acc = pd.read_csv("Downloads/FARS2015NationalCSV/ACC_AUX.csv")
per = pd.read_csv("Downloads/FARS2015NationalCSV/PER_AUX.csv")
veh = pd.read_csv("Downloads/FARS2015NationalCSV/VEH_AUX.csv")

# %%
acc.head(5)
# Out:
#    YEAR    STATE  ST_CASE  COUNTY  FATALS            A_CRAINJ  \
# 0  2015  Alabama    10001     127       1  Fatal Crash (FARS)
# 1  2015  Alabama    10002      83       1  Fatal Crash (FARS)
# 2  2015  Alabama    10003      11       1  Fatal Crash (FARS)
# 3  2015  Alabama    10004      45       1  Fatal Crash (FARS)
# 4  2015  Alabama    10005      45       1  Fatal Crash (FARS)
#
#                                             A_REGION   A_RU         A_INTER  \
# 0  Alabama, Florida, Georgia, South Carolina, Ten...  Rural  Non-Interstate
# 1  Alabama, Florida, Georgia, South Carolina, Ten...  Rural      Interstate
# 2  Alabama, Florida, Georgia, South Carolina, Ten...  Rural  Non-Interstate
# 3  Alabama, Florida, Georgia, South Carolina, Ten...  Rural  Non-Interstate
# 4  Alabama, Florida, Georgia, South Carolina, Ten...  Urban  Non-Interstate
#
#               A_RELRD     ...          A_D16_19     A_D15_20     A_D16_20  \
# ...

# %%
acc.shape
# Out:
# (32166, 38)

# %% [raw]
# acc.groupby(by='State').sum().round().sort_values('county', ascending=False)
